# %%
import json
import requests
from github import Github
import mysql.connector
from mysql.connector import errorcode
import sys
repos=[]

#Access token for the Github API
access_token='102c9d7018b6f5083deb9baad481f5c966815a3c'

#Helper function for getting responses

def getResponse(url):
    response=requests.get(url)
    d=response.headers.items()
    #print 'response.status_code is ',response.status_code
    link=""
    for (k,v) in response.headers.items():
        if k=="link":
            link=v
    return response.status_code,link,response.json()

#This API would return the the link in the 
#LinkHeader and a boolean value of True if that link was not the last

def followLink(linkHeader):
    links=linkHeader.split(';')
    link1=links[0]
    temp=links[1].split(',')
    link2=temp[1]
    link2=link2.lstrip()
    link2=link2.rstrip()
    link2=link2[1:-1]
    link1=link1[1:-1]
    print 'in followLinks link1 is : ',link1 ,' link2 is : ',link2,'\n\n'
    if link1==link2:
        return (link1,False)
    else:
        return (link1,True)
    

#API to get the number of followers of a user
def getNumberOfFollowers(link):
    link=link+'?access_token='+access_token+"&per_page=100"
    linkHeader=""
    response=requests.get(link)
    numFollowers=len(response.json())
    for (k,v) in response.headers.items():
        if k=='Link':
            linkHeader=v
    if(linkHeader==""):
        #means that there is only one page of followers
        return numFollowers
    flag=True
    followers=0
    while(flag):
        (link,flag)=followLink(linkHeader)
        response=requests.get(link)
        numFollowers+=len(response.json())
        for (k,v) in response.headers.items():
            if k=='link':
                linkHeader=v
    return numFollowers
    

def printInfo(user,body):
    for (k,v) in user.items():
        print k,' : ',v
    print 'body : ',body
    print '\n\n'
        


f = open('repos.txt', 'r')
for line in f:
    line=line.split('\n')[0]
    line=line+'?access_token='+access_token
    print 'line = ',line
    repos.append(line)


    
#Connecting to the database
config = {
  'user': 'root',
  'password': 'resnick1',
  'host': '127.0.0.1',
  'database': 'UserComments',
  'raise_on_warnings': True,
}

#Different Queries for MySQL
#Add a comment for a new userid
add_comment = ("INSERT INTO comments "
           "(login,id,commented_repo,avatar_url,gravatar_id,followers_url,following_url,gists_url,starred_url,subscriptions_url,organizations_url,repos_url,events_url,received_events_url,type,body) "
           "VALUES (%s, %s, %s, %s, %s,%s, %s, %s, %s, %s,%s, %s, %s, %s, %s,%s)")

#Update a comment for a existing user with the separator #NEWCOMMENT#
update_comment=("UPDATE comments SET body=CONCAT(body,%s) where id = %s")
#Query to check if a user with a id already exists or not
checkId = ("SELECT COUNT(*) FROM comments WHERE id=%s")

#Connect to the MySql server.

try:
    cnx = mysql.connector.connect(**config)len(response.json())
    cursor = cnx.cursor()

except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)
    cnx.close()
    sys.exit()
    
#Iterate through the repositories

for repo in repos:
    #print 'repo is ',repo,'hi'
    (code,link,responses)=getResponse(repo)
    flag=True
    print 'Got Status ',code,' for ',repo
    if code!=200:
        continue
    
    while(flag):    
        
        #Now we iterate through the current responses
        
        for response in responses:
            user=response["user"]
            body=response["body"]
            userid=user["id"]
            cursor.execute(checkId,(userid,))
            (userExists,)=cursor.fetchone()
            #printInfo(user,body)
            try:
                if userExists==0:
                    cursor.execute(add_comment,(user["login"],user["id"],repo,user["avatar_url"],user["gravatar_id"],user["followers_url"],user["following_url"],user["gists_url"],user["starred_url"],user["subscriptions_url"],user["organizations_url"],user["repos_url"],user["events_url"],user["received_events_url"],user["type"],body))
                else:
                    new_comment=" #NEWCOMMENT# "+body
                    cursor.execute(update_comment,(new_comment,userid))

                cnx.commit()
            except:
                pass
        #link1=link1+'?access_token='+access_token
        flag=False
        if link!="":
            (link1,flag)=followLink(link)
            (code,link,responses)=getResponse(link1)
        #print 'just hit ',link1,' with code ',code,'\n\n'
             if(code!=200):
                print 'Code : ',code,' Cannot continue for link ',link1
                break;
        
cursor.close()
cnx.close()
# Out:
# line =  https://api.github.com/repos/twbs/bootstrap/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9
# Got Status  200  for  https://api.github.com/repos/twbs/bootstrap/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=2  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=2  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=3  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=3  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=4  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=4  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=5  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=5  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=6  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=6  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=7  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=7  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=8  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=8  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=9  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
#
#
# in followLinks link1 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=9  link2 is :  https://api.github.com/repositories/2126244/comments?access_token=0231643decfea4f7c1d16fdcf893dc6b85592da9&page=48
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7c8e0c372671> in <module>()
#     141             userid=user["id"]
#     142             cursor.execute(checkId,(userid,))
# --> 143             (userExists,)=cursor.fetchone()
#     144             #printInfo(user,body)
#     145             try:
#
# TypeError: 'NoneType' object is not iterable
